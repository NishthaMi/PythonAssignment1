# %% [markdown]
# <a href="https://colab.research.google.com/github/NishthaMi/PythonAssignment1/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gym
# !pip install tensorflow
# !pip install numpy
# Dummy mock classes to simulate behavior (replace with actual implementations)
class LocalRunner:
    def __init__(self, sess=None):
        pass
    def setup(self, algo, env):
        pass
    def train(self, **kwargs):
        return 25  # dummy average return

class EpsilonGreedyStrategy:
    def __init__(self, **kwargs):
        pass

class DQN:
    def __init__(self, env_spec, exploration_strategy):
        pass

import gym

def test_dqn_cartpole():
    n_epochs = 10
    n_epoch_cycles = 10
    sampler_batch_size = 500
    num_timesteps = n_epochs * n_epoch_cycles * sampler_batch_size
    env = gym.make('CartPole-v0')

    epsilon_greedy_strategy = EpsilonGreedyStrategy(
        env_spec=env.spec,
        total_timesteps=num_timesteps
    )

    algo = DQN(
        env_spec=env.spec,
        exploration_strategy=epsilon_greedy_strategy
    )

    runner = LocalRunner()
    runner.setup(algo, env)
    last_avg_ret = runner.train(
        n_epochs=n_epochs,
        n_epoch_cycles=n_epoch_cycles,
        batch_size=sampler_batch_size
    )

    assert last_avg_ret > 20
    print("Test passed with avg return:", last_avg_ret)

# Run the test
test_dqn_cartpole()
# Out:
# ...
# Test passed with avg return: 25
# /usr/local/lib/python3.11/dist-packages/gym/envs/registration.py:593: UserWarning: WARN: The environment CartPole-v0 is out of date. You should consider upgrading to version `v1`.
#   logger.warn(
# /usr/local/lib/python3.11/dist-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.11/dist-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
